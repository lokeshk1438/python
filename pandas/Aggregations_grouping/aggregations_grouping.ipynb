# %%
# link used for below task
# https://www.kaggle.com/akshaysehgal/ultimate-guide-to-pandas-groupby-aggregate

# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv(r"titanic_data.csv")
df = df.dropna() # remove na values

# %%
print(df.shape)
df.head()
# Out:
# (182, 15)
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
# Question: What is the total number of passengers from each class who survived?

# %%
df.groupby('class')['survived'].size()
# Out:
# class
# First     157
# Second     15
# Third      10
# Name: survived, dtype: int64

# %%
grouper = df.groupby('class')

# %%
grouper['survived'].sum()
# Out:
# class
# First     106
# Second     12
# Third       5
# Name: survived, dtype: int64

# %%
df[df['class']=='Third'].reset_index()

# df.query("df['class'] == 'Third'")
# Out:
#    index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0     10         1       3  female   4.0      1      1  16.7000        S
# 1     75         0       3    male  25.0      0      0   7.6500        S
# 2    205         0       3  female   2.0      0      1  10.4625        S
# 3    250         0       3  female  29.0      1      1  10.4625        S
# 4    393         1       3  female  24.0      0      2  16.7000        S
# 5    428         1       3    male  32.0      0      0   8.0500        S
# 6    697         0       3    male  42.0      0      0   7.6500        S
# 7    713         0       3    male  19.0      0      0   7.6500        S
# 8    749         1       3    male   6.0      0      1  12.4750        S
# 9    821         1       3  female  27.0      0      1  12.4750        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third  child       False    G  Southampton   yes  False
# ...

# %%
# Question: What was the average fare for passengers from each town?

# %%
df.groupby('embark_town')['fare'].mean().reset_index()
# Out:
#    embark_town        fare
# 0    Cherbourg  103.342503
# 1   Queenstown   90.000000
# 2  Southampton   64.922862

# %%
# Question: What was the average fare for male vs female passengers from each town?

# %%
df.groupby(['embark_town', 'sex'])['fare'].mean().reset_index()
# Out:
#    embark_town     sex        fare
# 0    Cherbourg  female  104.169609
# 1    Cherbourg    male  102.435355
# 2   Queenstown  female   90.000000
# 3   Queenstown    male   90.000000
# 4  Southampton  female   79.251179
# 5  Southampton    male   52.674461

# %%
df.groupby(['sex', 'embark_town'])['fare'].mean().reset_index()
# Out:
#       sex  embark_town        fare
# 0  female    Cherbourg  104.169609
# 1  female   Queenstown   90.000000
# 2  female  Southampton   79.251179
# 3    male    Cherbourg  102.435355
# 4    male   Queenstown   90.000000
# 5    male  Southampton   52.674461

# %%
# Question: What was the average fare and age for male vs female passengers from each town?

# %%
df.groupby(['embark_town', 'sex'])[['fare', 'age']].mean().reset_index()
# Out:
#    embark_town     sex        fare        age
# 0    Cherbourg  female  104.169609  35.352941
# 1    Cherbourg    male  102.435355  39.774194
# 2   Queenstown  female   90.000000  33.000000
# 3   Queenstown    male   90.000000  44.000000
# 4  Southampton  female   79.251179  30.952830
# 5  Southampton    male   52.674461  37.595484

# %% [markdown]
# ## Grouping

# %% [markdown]
# indepth understanding

# %%
grouper = df.groupby(['embark_town'])

# %%
[(type(k), type(v)) for k,v in grouper]
# Out:
# [(str, pandas.core.frame.DataFrame),
#  (str, pandas.core.frame.DataFrame),
#  (str, pandas.core.frame.DataFrame)]

# %%
# [(k, v) for k,v in grouper]

# %%
[(k, g.shape) for k, g in grouper]
# Out:
# [('Cherbourg', (65, 15)), ('Queenstown', (2, 15)), ('Southampton', (115, 15))]

# %%
list(grouper)[0][0] # grouped column
# Out:
# 'Cherbourg'

# %%
list(grouper)[0][1]  # dataframe for the grouped column
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 52          1       1  female  49.0      1      0   76.7292        C   First
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 97          1       1    male  23.0      0      1   63.3583        C   First
# 118         0       1    male  24.0      0      1  247.5208        C   First
# 139         0       1    male  24.0      0      0   79.2000        C   First
# 174         0       1    male  56.0      0      0   30.6958        C   First
# 177         0       1  female  50.0      0      0   28.7125        C   First
# 194         1       1  female  44.0      0      0   27.7208        C   First
# 195         1       1  female  58.0      0      0  146.5208        C   First
# ...

# %%
# grouping under multiple columns

# %%
grouper = df.groupby(['embark_town','sex'])

# %%
[(k, g.shape) for k, g in grouper]
# Out:
# [(('Cherbourg', 'female'), (34, 15)),
#  (('Cherbourg', 'male'), (31, 15)),
#  (('Queenstown', 'female'), (1, 15)),
#  (('Queenstown', 'male'), (1, 15)),
#  (('Southampton', 'female'), (53, 15)),
#  (('Southampton', 'male'), (62, 15))]

# %%
# list(grouper)[1][1]['age'].mean()

list(grouper)[1][1]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 54          0       1  male  65.0      0      1   61.9792        C   First
# 96          0       1  male  71.0      0      0   34.6542        C   First
# 97          1       1  male  23.0      0      1   63.3583        C   First
# 118         0       1  male  24.0      0      1  247.5208        C   First
# 139         0       1  male  24.0      0      0   79.2000        C   First
# 174         0       1  male  56.0      0      0   30.6958        C   First
# 209         1       1  male  40.0      0      0   31.0000        C   First
# 272         0       1  male  37.0      0      1   29.7000        C   First
# 291         0       2  male  36.0      0      0   12.8750        C  Second
# 369         1       1  male  25.0      1      0   55.4417        C   First
# 376         0       1  male  27.0      0      2  211.5000        C   First
# ...

# %%
grouper['age'].mean() # or list(grouper)[1][1]['age'].mean() --> for only one of the grouped object
# Out:
# embark_town  sex
# Cherbourg    female    35.352941
#              male      39.774194
# Queenstown   female    33.000000
#              male      44.000000
# Southampton  female    30.952830
#              male      37.595484
# Name: age, dtype: float64

# %% [markdown]
# ## Aggregation

# %%
# Function	Description
# mean( )	Compute mean of groups
# median( )	Compute median of groups
# mode( )	Compute mode of groups
# sum( )	Compute sum of group values
# prod( )	Compute product of group values
# size( )	Compute group sizes
# count( )	Compute count of group
# std( )	Standard deviation of groups
# var( )	Compute variance of groups
# skew( )	Compute skewness/3rd moment of groups
# kurt( )	Compute kurtosis/4th moment of groups
# sem( )	Standard error of the mean of groups
# mad( )	Mean absolute deviation for each group
# describe( )	Generates descriptive statistics
# first( )	Compute first of group values
# last( )	Compute last of group values
# nth( )	Take nth value, or a subset if n is a list
# min( )	Compute min of group values
# max( )	Compute max of group values

# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.apply.html

# %%
# Question: Get the unique set of ages for all each age category (who column) from each town.

# %%
df.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
df.groupby(['embark_town','who']).size()
# Out:
# embark_town  who
# Cherbourg    man      31
#              woman    34
# Queenstown   man       1
#              woman     1
# Southampton  child    13
#              man      55
#              woman    47
# dtype: int64

# %%
df.groupby(['embark_town','who'])['age'].apply(set).reset_index()
# Out:
#    embark_town    who  \
# 0    Cherbourg    man
# 1    Cherbourg  woman
# 2   Queenstown    man
# 3   Queenstown  woman
# 4  Southampton  child
# 5  Southampton    man
# 6  Southampton  woman
#
#                                                                                                                                                                                                             age
# 0                                                                          {17.0, 18.0, 23.0, 24.0, 25.0, 26.0, 27.0, 30.0, 32.0, 35.0, 36.0, 37.0, 40.0, 46.0, 48.0, 49.0, 50.0, 56.0, 58.0, 60.0, 65.0, 71.0}
# 1                                                        {16.0, 17.0, 18.0, 19.0, 21.0, 22.0, 23.0, 24.0, 30.0, 31.0, 32.0, 36.0, 38.0, 39.0, 40.0, 41.0, 44.0, 48.0, 49.0, 50.0, 52.0, 54.0, 56.0, 58.0, 60.0}
# ...

# %%
# Question: Get the range (min - max) of ages for each age category (who column) from each town.

# %%
df.groupby(['embark_town','who'])['age'].apply(lambda x: (x.max()-x.min())).reset_index()
# Out:
#    embark_town    who    age
# 0    Cherbourg    man  54.00
# 1    Cherbourg  woman  44.00
# 2   Queenstown    man   0.00
# 3   Queenstown  woman   0.00
# 4  Southampton  child  14.08
# 5  Southampton    man  61.00
# 6  Southampton  woman  47.00

# %%
grouper_who = df.groupby(['embark_town','who'])

# %%
[(k, g.shape) for k,g in grouper_who]
# Out:
# [(('Cherbourg', 'man'), (31, 15)),
#  (('Cherbourg', 'woman'), (34, 15)),
#  (('Queenstown', 'man'), (1, 15)),
#  (('Queenstown', 'woman'), (1, 15)),
#  (('Southampton', 'child'), (13, 15)),
#  (('Southampton', 'man'), (55, 15)),
#  (('Southampton', 'woman'), (47, 15))]

# %%
list(grouper_who)[4][1]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 296         0       1  female   2.00      1      2  151.5500        S   First
# 304         1       1    male   0.92      1      2  151.5500        S   First
# 339         1       2    male   2.00      1      1   26.0000        S  Second
# 434         1       1  female  14.00      1      2  120.0000        S   First
# 444         1       1    male   4.00      0      2   81.8583        S   First
# 616         1       2  female   4.00      2      1   39.0000        S  Second
# 687         1       1  female  15.00      0      1  211.3375        S   First
# ...

# %%
print("max in group age: ", list(grouper_who)[4][1]['age'].max())
print("min in group age: ", list(grouper_who)[4][1]['age'].min())
# Out:
# max in group age:  15.0
# min in group age:  0.92

# %%
# Question: Get the mean fare by age ratio for each age category (who column) from each town.

# %%
df.groupby(['embark_town','who']).apply(lambda x: (x['fare']/x['age']).mean())
# Out:
# embark_town  who
# Cherbourg    man       3.146083
#              woman     3.614103
# Queenstown   man       2.045455
#              woman     2.727273
# Southampton  child    28.956893
#              man       1.410745
#              woman     2.593897
# dtype: float64

# %%
# # multiple aggregations
# ##Single function per column
# {
#  'column1': 'function1', 
#  'column2': 'function2'
# }

# ##Multiple functions per column
# {
#  'column1': ['function1', 'function2'], 
#  'column2': ['function3', 'function4']
# }

# %%
# Question: Get the mean of fare, AND median of age for each age category (who column) from each town

# %%
# 1 column 1 function
agg_func = {
    'fare' : 'mean',
    'age' : 'median'
}

# %%
df.groupby(['embark_town', 'who']).agg(agg_func).reset_index()
# Out:
#    embark_town    who        fare   age
# 0    Cherbourg    man  102.435355  36.0
# 1    Cherbourg  woman  104.169609  37.0
# 2   Queenstown    man   90.000000  44.0
# 3   Queenstown  woman   90.000000  33.0
# 4  Southampton  child   77.379485   4.0
# 5  Southampton    man   51.071515  40.0
# 6  Southampton  woman   77.686436  33.0

# %%
# Question: Get the sum & mean of fare, AND median, min and max of age for each age category (who column) from each town

# %%
agg_func_1 = {
    'fare' : ['mean', 'sum'],
    'age' : ['min', 'max', 'median']
}

# %%
df.groupby(['embark_town', 'who']).agg(agg_func_1).reset_index()
# Out:
#    embark_town    who        fare               age
#                              mean        sum    min   max median
# 0    Cherbourg    man  102.435355  3175.4960  17.00  71.0   36.0
# 1    Cherbourg  woman  104.169609  3541.7667  16.00  60.0   37.0
# 2   Queenstown    man   90.000000    90.0000  44.00  44.0   44.0
# 3   Queenstown  woman   90.000000    90.0000  33.00  33.0   33.0
# 4  Southampton  child   77.379485  1005.9333   0.92  15.0    4.0
# 5  Southampton    man   51.071515  2808.9333  19.00  80.0   40.0
# 6  Southampton  woman   77.686436  3651.2625  16.00  63.0   33.0

# %%
# custom functions

# %%
agg_cust = {
    'fare':lambda x: x.sum(), 
    'age' :lambda x: x.max()
}

# %%
df.groupby(['embark_town', 'who']).agg(agg_cust).reset_index()
# Out:
#    embark_town    who       fare   age
# 0    Cherbourg    man  3175.4960  71.0
# 1    Cherbourg  woman  3541.7667  60.0
# 2   Queenstown    man    90.0000  44.0
# 3   Queenstown  woman    90.0000  33.0
# 4  Southampton  child  1005.9333  15.0
# 5  Southampton    man  2808.9333  80.0
# 6  Southampton  woman  3651.2625  63.0

# %% [markdown]
# ## Transform

# %%
# Question: Create a new column that returns the average fare for the age group (who column) the passenger belongs to.

# %%
df.groupby('who')['fare'].transform('mean')
# Out:
# 1      88.817429
# 3      88.817429
# 6      69.821026
# 10     77.379485
# 11     88.817429
# 21     69.821026
# 23     69.821026
# 27     69.821026
# 52     88.817429
# 54     69.821026
# 62     69.821026
# 66     88.817429
# 75     69.821026
# 88     88.817429
# 92     69.821026
# 96     69.821026
# 97     69.821026
# 102    69.821026
# 110    69.821026
# 118    69.821026
# 123    88.817429
# 124    69.821026
# 136    88.817429
# 137    69.821026
# 139    69.821026
# 148    69.821026
# 151    88.817429
# 170    69.821026
# 174    69.821026
# 177    88.817429
# 183    77.379485
# 193    77.379485
# 194    88.817429
# 195    88.817429
# 205    77.379485
# 209    69.821026
# 214    88.817429
# 217    88.817429
# 223    69.821026
# 229    88.817429
# 244    69.821026
# 247    69.821026
# 250    88.817429
# 251    69.821026
# 256    88.817429
# 261    69.821026
# 262    69.821026
# 267    88.817429
# 268    88.817429
# 272    69.821026
# 274    88.817429
# 290    88.817429
# ...

# %%
df.groupby('who')['fare'].transform(lambda x: x.mean())
# Out:
# 1      88.817429
# 3      88.817429
# 6      69.821026
# 10     77.379485
# 11     88.817429
# 21     69.821026
# 23     69.821026
# 27     69.821026
# 52     88.817429
# 54     69.821026
# 62     69.821026
# 66     88.817429
# 75     69.821026
# 88     88.817429
# 92     69.821026
# 96     69.821026
# 97     69.821026
# 102    69.821026
# 110    69.821026
# 118    69.821026
# 123    88.817429
# 124    69.821026
# 136    88.817429
# 137    69.821026
# 139    69.821026
# 148    69.821026
# 151    88.817429
# 170    69.821026
# 174    69.821026
# 177    88.817429
# 183    77.379485
# 193    77.379485
# 194    88.817429
# 195    88.817429
# 205    77.379485
# 209    69.821026
# 214    88.817429
# 217    88.817429
# 223    69.821026
# 229    88.817429
# 244    69.821026
# 247    69.821026
# 250    88.817429
# 251    69.821026
# 256    88.817429
# 261    69.821026
# 262    69.821026
# 267    88.817429
# 268    88.817429
# 272    69.821026
# 274    88.817429
# 290    88.817429
# ...

# %%
# df.groupby('embark_town').size().reset_index()

temp_df = df.query("embark_town=='Cherbourg'")
temp_df.head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# 54          0       1    male  65.0      0      1   61.9792        C  First
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 97          1       1    male  23.0      0      1   63.3583        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
# 139         0       1    male  24.0      0      0   79.2000        C  First
# 174         0       1    male  56.0      0      0   30.6958        C  First
# 177         0       1  female  50.0      0      0   28.7125        C  First
# 194         1       1  female  44.0      0      0   27.7208        C  First
#
#        who  adult_male deck embark_town alive  alone
# 1    woman       False    C   Cherbourg   yes  False
# ...

# %%
cust_func = {
    'age' : ['max', 'min'],
    'deck' : lambda x: tuple(set(x))
}

# %%
temp_df_1 = temp_df.groupby('who').agg(cust_func).reset_index()

# %%
temp_df_1
# Out:
#      who   age                   deck
#            max   min         <lambda>
# 0    man  71.0  17.0  (C, E, A, B, D)
# 1  woman  60.0  16.0  (C, E, A, B, D)

# %%
temp_df_1.columns
# Out:
# MultiIndex([( 'who',         ''),
#             ( 'age',      'max'),
#             ( 'age',      'min'),
#             ('deck', '<lambda>')],
#            )

# %%
df.shape
# Out:
# (182, 15)

# %%
df.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
grouped_1 = df.groupby('who')

# %%
[(k, g.shape) for k, g in grouped_1]
# Out:
# [('child', (13, 15)), ('man', (87, 15)), ('woman', (82, 15))]

# %%
temp_df = grouped_1.get_group('child')
list(grouped_1)[0][1].reset_index() # or grouped_1.get_group('child')
# Out:
#     index  survived  pclass     sex    age  sibsp  parch      fare embarked  \
# 0      10         1       3  female   4.00      1      1   16.7000        S
# 1     183         1       2    male   1.00      2      1   39.0000        S
# 2     193         1       2    male   3.00      1      1   26.0000        S
# 3     205         0       3  female   2.00      0      1   10.4625        S
# 4     296         0       1  female   2.00      1      2  151.5500        S
# 5     304         1       1    male   0.92      1      2  151.5500        S
# 6     339         1       2    male   2.00      1      1   26.0000        S
# 7     434         1       1  female  14.00      1      2  120.0000        S
# 8     444         1       1    male   4.00      0      2   81.8583        S
# 9     616         1       2  female   4.00      2      1   39.0000        S
# 10    687         1       1  female  15.00      0      1  211.3375        S
# ...

# %%
temp_df.agg(
    min_age = pd.NamedAgg(column="age", aggfunc='min')
) # aggregate functions
# Out:
#           age
# min_age  0.92

# %%
temp_df.sort_values(['sex'])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 296         0       1  female   2.00      1      2  151.5500        S   First
# 434         1       1  female  14.00      1      2  120.0000        S   First
# 616         1       2  female   4.00      2      1   39.0000        S  Second
# 687         1       1  female  15.00      0      1  211.3375        S   First
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 304         1       1    male   0.92      1      2  151.5500        S   First
# 339         1       2    male   2.00      1      1   26.0000        S  Second
# 444         1       1    male   4.00      0      2   81.8583        S   First
# ...

# %%
def min_age(x):
    display("object: ", x)
    display("min_value: ", x.min())
    return x.min()

def collect_set(x):
    display("object: ", x)
    display("collected set:", set(x))
    return set(x)

# %%
temp_df.assign(
    min_age = temp_df.groupby('sex')['age'].transform(lambda x: min_age(x))
).sort_values(['sex', 'min_age'])
# Out:
# 'object: '
# 10      4.0
# 205     2.0
# 296     2.0
# 434    14.0
# 616     4.0
# 687    15.0
# Name: female, dtype: float64
# 'min_value: '
# 2.0
# 'object: '
# 183     1.00
# 193     3.00
# 304     0.92
# 339     2.00
# 444     4.00
# 749     6.00
# 800    11.00
# Name: male, dtype: float64
# 'min_value: '
# 0.92
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 296         0       1  female   2.00      1      2  151.5500        S   First
# 434         1       1  female  14.00      1      2  120.0000        S   First
# 616         1       2  female   4.00      2      1   39.0000        S  Second
# 687         1       1  female  15.00      0      1  211.3375        S   First
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# ...

# %%
temp_df.groupby('sex')['deck'].apply(lambda x: collect_set(x)) # returns a scalar object
# Out:
# 'object: '
# 10     G
# 205    G
# 296    C
# 434    B
# 616    F
# 687    B
# Name: female, dtype: object
# 'collected set:'
# {'B', 'C', 'F', 'G'}
# 'object: '
# 183    F
# 193    F
# 304    C
# 339    F
# 444    A
# 749    E
# 800    B
# Name: male, dtype: object
# 'collected set:'
# {'A', 'B', 'C', 'E', 'F'}
# sex
# female       {C, F, G, B}
# male      {C, E, A, B, F}
# Name: deck, dtype: object

# %%
temp_df.sort_values('sex')
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 296         0       1  female   2.00      1      2  151.5500        S   First
# 434         1       1  female  14.00      1      2  120.0000        S   First
# 616         1       2  female   4.00      2      1   39.0000        S  Second
# 687         1       1  female  15.00      0      1  211.3375        S   First
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 304         1       1    male   0.92      1      2  151.5500        S   First
# 339         1       2    male   2.00      1      1   26.0000        S  Second
# 444         1       1    male   4.00      0      2   81.8583        S   First
# ...

# %%
temp_df['temp_col'] = temp_df.groupby('sex')['deck'].transform(lambda x: 50) # broadcasting a scalar value to all the grouped object
# Out:
# C:\Users\lkoturu\AppData\Local\Temp/ipykernel_7500/2364898698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['temp_col'] = temp_df.groupby('sex')['deck'].transform(lambda x: 50) # broadcasting a scalar value to all the grouped object

# %%
def transform_scalar(x):
    display(x)
    return np.array(set(x))
#     return x.min()

# %%
temp_df.groupby('sex')['fare'].transform(lambda x: transform_scalar(x) )
# Out:
# 10      16.7000
# 205     10.4625
# 296    151.5500
# 434    120.0000
# 616     39.0000
# 687    211.3375
# Name: female, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7500/2776088204.py in <module>
# ----> 1 temp_df.groupby('sex')['fare'].transform(lambda x: transform_scalar(x) )
#
# C:\Program Files (x86)\Python38-32\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     503     @Appender(_transform_template)
#     504     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 505         return self._transform(
#     506             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     507         )
#
# ...

# %%
temp_df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 193         1       2    male   3.00      1      1   26.0000        S  Second
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 296         0       1  female   2.00      1      2  151.5500        S   First
# 304         1       1    male   0.92      1      2  151.5500        S   First
# 339         1       2    male   2.00      1      1   26.0000        S  Second
# 434         1       1  female  14.00      1      2  120.0000        S   First
# 444         1       1    male   4.00      0      2   81.8583        S   First
# 616         1       2  female   4.00      2      1   39.0000        S  Second
# 687         1       1  female  15.00      0      1  211.3375        S   First
# ...

# %%
# funcs = {'age': ['min', 'max'], 'deck': lambda x: set(x)}


funcs = {
    'min_age' : pd.NamedAgg(column='age', aggfunc='min'),
    'max_age' : pd.NamedAgg(column='age', aggfunc='max'),
    'combined' : pd.NamedAgg(column='deck', aggfunc=lambda x: set(x))
}

# %%
temp_df.groupby('sex').agg(
    **funcs
).reset_index()
# Out:
#       sex  min_age  max_age         combined
# 0  female     2.00     15.0     {C, F, G, B}
# 1    male     0.92     11.0  {C, E, A, B, F}
